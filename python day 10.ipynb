# %%
def evenorodd(n):
    if n % 2:
       return"odd"
    else:
        return "Even"
res=evenorodd(10)
print(res)
# Out:
# Even

# %%
def evenorodd(n):
    if n % 2:
       return False
    else:
        return True
res=evenorodd(10)
print(res)
if res ==True:
    print("number is even")
else:
    print("number is odd")
# Out:
# True
# number is even

# %%
def evenorodd(n):
    if n % 2:
       return ("odd")
    else:
        return ("even")
res=evenorodd(10)
print(res)
if res ==True:
    print("number is even")
else:
    print("number is odd")
# Out:
# even
# number is odd

# %% [markdown]
# #### Types of Arguments
# 1. positional Arguments
# 2. KeywordArguments
# 3. Default Arguments
# 4. varible lenths positional of arguments
# 5. veriable length of keyword arguments

# %%
#positional arguments
#subtraction of two numbers using functions
def sub(n1,n2):
    res =n1-n2
    return res
a=int(input())
b=int(input())
print(sub(b,a))
# Out:
#  10
#  5
# -5

# %%
def sub(n1,n2):
    res =n1-n2
    return res
a,b=10,5
print(sub(a,b))
print(sub(b,a))
# Out:
# 5
# -5

# %%
#list is mutable
lst=[1,2,3,40,'hi','hello']
lst[0]=100
print(lst)
# Out:
# [100, 2, 3, 40, 'hi', 'hello']

# %%
lst=[10,2,4,4.534,534,'hi','hello']
print(lst[2])
print(lst[-3])
print(lst[2:])
# Out:
# 4
# 534
# [4, 4.534, 534, 'hi', 'hello']

# %%
#string is immutable
k='lokesh'
k[0]='e'
print(s)

# %%
#reading list of elements from user
l=map(int,input().split())
print(type(1),1)
# Out:
#  1 2 3 4
# <class 'int'> 1

# %%
#reading list of integer elements from user
l = list(map(int,input().split()))
print(type(1), 1)
# Out:
#  1 2 3 4 5
# <class 'int'> 1

# %%
#read list of number and if number is even and if number is odd add 1
#lst=[1,2,3,4,5]
#res=[2,2.5,4,4.5,6]
lst = list(map(int,input().split()))
for i in range(0, len(lst)):
    if lst[i] % 2:
        lst[i]=lst[i]+1
    else:
        lst[i]+=0.5
print(lst)
# Out:
#  1 2 3 4 5
# [2, 2.5, 4, 4.5, 6]
