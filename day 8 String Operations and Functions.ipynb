# %%
#sum of two numbers
n1=int(input())
n2=int(input())
s=n1+n2
print(f'sum of two numbers {n1} and {n2} is:{s}')
# Out:
#  4
#  5
# sum of two numbers 4 and 5 is:9

# %%
#In functions
#Function definition
def sum_of_two_numbers(a,b):#parameter
    s=a+b
    return s
#Function call
res=sum_of_two_numbers(10,20)#arguments
print(res)
# Out:
# 30

# %%
#Functions program
def addition(a,b):
    return a+b
def subtraction(a,b):
    return a-b
def multiplication(a,b):
    return a*b
def division(a,b):
    if b == 0:
        return "zero division not possible"
    return a / b
if __name__=="__main__":
    print("Welcome to small level calculator")
    n1= int(input("Enter number 1:"))
    n2= int(input("Enter number 2:"))
    print("1. Addition \n2. subtraction \n3. Multiplication \n4. Division")
    choice=int(input("Enter your choice:"))
    if choice == 1:
               print("sum of two number is:", addition(n1,n2))
    elif choice == 2:
                print("subtraction of two number is:", subtraction(n1,n2))
    elif choice == 3:
                print("multipication of two number is:", multiplication(n1,n2))
    elif choice == 4:
                print("Division of two number is:", division(n1,n2))
    else:
        print("please select correct option")
Welcome to small level calculator
1. Addition 
2. subtraction 
3. Multiplication 
4. Division
multipication of two number is: 1608
# Out:
#   Cell In[4], line 28
#     Welcome to small level calculator
#             ^
# SyntaxError: invalid syntax
